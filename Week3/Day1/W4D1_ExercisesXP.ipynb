# %%
# !pip install kaggle

# Upload kaggle.json file (Run this cell and select your kaggle.json file through the file picker)
from google.colab import files
uploaded = files.upload()

# Make directory named kaggle and copy kaggle.json file there
# !mkdir ~/.kaggle
# !cp kaggle.json ~/.kaggle/

# Change the permissions of the file
# !chmod 600 ~/.kaggle/kaggle.json
# Out:
# ...
#      <input type="file" id="files-e8f9b58c-83d0-4195-8b24-658d05362883" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e8f9b58c-83d0-4195-8b24-658d05362883">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# ## **Exercise 1: Introduction To Data Analysis (Easy)**
#
# **What is data analysis?**
# Data analysis is the systematic process of inspecting, cleaning, transforming, and modeling data to uncover meaningful insights, draw conclusions, and support decision-making. In today's data-driven world, data analysis plays a pivotal role across various industries, ranging from business and finance to healthcare, education, and beyond.In today's data-driven world, data analysis plays a pivotal role across various industries, ranging from business and finance to healthcare, education, and beyond.
#
# **Why is data analysis important in modern contexts?**
# In the age of information, where data is generated at an unprecedented rate from various sources, data analysis emerges as a crucial tool for unlocking insights, driving innovation, and making informed decisions across diverse domains. From business and healthcare to science, education, and beyond, the importance of data analysis in modern contexts cannot be overstated. Data analysis is indispensable in modern contexts due to its ability to extract actionable insights from data, drive innovation, and facilitate evidence-based decision-making across various domains. As the volume, velocity, and variety of data continue to grow exponentially, the demand for skilled data analysts and data-driven approaches will only intensify. Embracing data analysis as a strategic asset enables individuals, organizations, and societies to harness the power of data to address complex challenges and seize opportunities in an increasingly interconnected world.
#
# **List and describe three areas where data analysis is applied today.**
# Business and Marketing: Data analysis is extensively applied in business and marketing to understand customer behavior, optimize operations, and drive growth. Business and Marketing: Data analysis is extensively applied in business and marketing to understand customer behavior, optimize operations, and drive growth. Finance and Economics: Data analysis is widely applied in finance and economics for risk management, investment decision-making, and economic forecasting.

# %% [markdown]
# ## **Exercise 2: Dataset Loading And Initial Analysis**
# ## **Exercise 3: Identifying Data Types**
# ## **Exercise 4: Exploring Data Types**
# ## **Exercise 5: Basic Data Analysis With Google Colab**
# ## **Exercise 6: Basic Observation Skills In Data Analysis**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
import pickle
import pandas as pd
# !kaggle datasets download -d thedevastator/how-much-sleep-do-americans-really-get
# Out:
# ...
#   0% 0.00/7.62k [00:00<?, ?B/s]
# 100% 7.62k/7.62k [00:00<00:00, 15.7MB/s]

# %%
# !unzip how-much-sleep-do-americans-really-get.zip
# Out:
# Archive:  how-much-sleep-do-americans-really-get.zip
#   inflating: Time Americans Spend Sleeping.csv

# %%
import pandas as pd
df = pd.read_csv('Time Americans Spend Sleeping.csv')

# %%
df.head()
# Out:
#    index  Year  Period  Avg hrs per day sleeping  Standard Error Type of Days  \
# 0      0  2003  Annual                      8.57           0.018     All days
# 1      1  2004  Annual                      8.55           0.026     All days
# 2      2  2005  Annual                      8.62           0.023     All days
# 3      3  2006  Annual                      8.63           0.024     All days
# 4      4  2007  Annual                      8.57           0.024     All days
#
#            Age Group  Activity   Sex
# 0  15 years and over  Sleeping  Both
# 1  15 years and over  Sleeping  Both
# 2  15 years and over  Sleeping  Both
# 3  15 years and over  Sleeping  Both
# 4  15 years and over  Sleeping  Both

# %%
print(df)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
print(df.columns)
# Out:
# Index([], dtype='object')

# %%
# mean_value_avg = df['Avg hrs per day sleeping'].mean()
# print("Mean:", mean_value_avg)
# median_value_avg = df['Avg hrs per day sleeping'].median()
# print("Median:", median_value_avg)
# mode_value_avg = df['Avg hrs per day sleeping'].mode()[0]
# print("Mode:", mode_value_avg)

# mean_value_error = df['Standard Error'].mean()
# print("Mean:", mean_value_error)
# median_value_error = df['Standard Error'].median()
# print("Median:", median_value_error)
# mode_value_error = df['Standard Error'].mode()[0]
# print("Mode:", mode_value_error)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 690 entries, 0 to 689
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Gender          690 non-null    int64
#  1   Age             690 non-null    float64
#  2   Debt            690 non-null    float64
#  3   Married         690 non-null    int64
#  4   BankCustomer    690 non-null    int64
#  5   Industry        690 non-null    object
#  6   Ethnicity       690 non-null    object
#  7   YearsEmployed   690 non-null    float64
#  8   PriorDefault    690 non-null    int64
#  9   Employed        690 non-null    int64
#  10  CreditScore     690 non-null    int64
#  11  DriversLicense  690 non-null    int64
#  12  Citizen         690 non-null    object
#  13  ZipCode         690 non-null    int64
#  14  Income          690 non-null    int64
#  15  Approved        690 non-null    int64
# dtypes: float64(3), int64(10), object(3)
# memory usage: 86.4+ KB

# %%
import matplotlib.pyplot as plt
plt.plot(df['Year'], df['Avg hrs per day sleeping'])
plt.show()

# %% [markdown]
#  Brief dataset description:
#  Year: The year in which the data was collected.
#  Period: The time period during which the data was collected.
#  Avg hrs per day sleeping: The average number of hours per day spent sleeping by the individuals surveyed.
# Standard Error: The standard error for the average number of hours per day Americans spend sleeping.
# Type of Days: The type of day the data was collected.
# Age Group: The age group of the Americans surveyed.
# Activity: The activity the Americans surveyed were engaged in.
# Sex: The sex of the Americans surveyed.
# Mostly we have string datas, but there is few integer and float

# %%
# !kaggle datasets download -d samuelcortinhas/credit-card-approval-clean-data
# Out:
# ...
#   0% 0.00/19.0k [00:00<?, ?B/s]
# 100% 19.0k/19.0k [00:00<00:00, 18.3MB/s]

# %%
# !unzip credit-card-approval-clean-data.zip
# Out:
# Archive:  credit-card-approval-clean-data.zip
#   inflating: clean_dataset.csv
#   inflating: crx.csv

# %%
import pandas as pd
df = pd.read_csv('clean_dataset.csv')

# %%
df.head()
# Out:
#    Gender    Age   Debt  Married  BankCustomer     Industry Ethnicity  \
# 0       1  30.83  0.000        1             1  Industrials     White
# 1       0  58.67  4.460        1             1    Materials     Black
# 2       0  24.50  0.500        1             1    Materials     Black
# 3       1  27.83  1.540        1             1  Industrials     White
# 4       1  20.17  5.625        1             1  Industrials     White
#
#    YearsEmployed  PriorDefault  Employed  CreditScore  DriversLicense  \
# 0           1.25             1         1            1               0
# 1           3.04             1         1            6               0
# 2           1.50             1         0            0               0
# 3           3.75             1         1            5               1
# 4           1.71             1         0            0               0
#
#         Citizen  ZipCode  Income  Approved
# 0       ByBirth      202       0         1
# ...

# %%
print(df.columns)
# Out:
# Index([], dtype='object')

# %%
# import pandas as pd
# mean_value_age = df['Age'].mean()
# print("Mean:", mean_value_age)
# median_value_age = df['Age'].median()
# print("Median:", median_value_age)
# mode_value_age = df['Age'].mode()[0]
# print("Mode:", mode_value_age)

# mean_value_db = df['Debt'].mean()
# print("Mean:", mean_value_db)
# median_value_db = df['Debt'].median()
# print("Median:", median_value_db)
# mode_value_db = df['Debt'].mode()[0]
# print("Mode:", mode_value_db)

# mean_value_empl = df['YearsEmployed'].mean()
# print("Mean:", mean_value_empl)
# median_value_empl = df['YearsEmployed'].median()
# print("Median:", median_value_empl)
# mode_value_empl = df['YearsEmployed'].mode()[0]
# print("Mode:", mode_value_empl)

# mean_value_score = df['CreditScore'].mean()
# print("Mean:", mean_value_score)
# median_value_score = df['CreditScore'].median()
# print("Median:", median_value_score)
# mode_value_score = df['CreditScore'].mode()[0]
# print("Mode:", mode_value_score)

# mean_value_income = df['Income'].mean()
# print("Mean:", mean_value_income)
# median_value_income = df['Income'].median()
# print("Median:", median_value_income)
# mode_value_income = df['Income'].mode()[0]
# print("Mode:", mode_value_income)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 690 entries, 0 to 689
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Gender          690 non-null    int64
#  1   Age             690 non-null    float64
#  2   Debt            690 non-null    float64
#  3   Married         690 non-null    int64
#  4   BankCustomer    690 non-null    int64
#  5   Industry        690 non-null    object
#  6   Ethnicity       690 non-null    object
#  7   YearsEmployed   690 non-null    float64
#  8   PriorDefault    690 non-null    int64
#  9   Employed        690 non-null    int64
#  10  CreditScore     690 non-null    int64
#  11  DriversLicense  690 non-null    int64
#  12  Citizen         690 non-null    object
#  13  ZipCode         690 non-null    int64
#  14  Income          690 non-null    int64
#  15  Approved        690 non-null    int64
# dtypes: float64(3), int64(10), object(3)
# memory usage: 86.4+ KB

# %% [markdown]
# Gender: The gender of the individual.
# Age: The age of the individual.
# Debt: The amount of debt the individual has.
# Married: Indicates whether the individual is married.
# BankCustomer: Indicates whether the individual is a bank customer.
# Industry: The industry or sector in which the individual works.
# Ethnicity: The ethnicity or cultural background of the individual.
# YearsEmployed: The number of years the individual has been employed.
# PriorDefault: Indicates whether the individual has a prior default history.
# Employed: Indicates whether the individual is currently employed.
# CreditScore: The credit score of the individual.
# DriversLicense: Indicates whether the individual has a driver's license.
# Citizen: Indicates the citizenship status of the individual.
# ZipCode: The zip code or postal code of the individual's location.
# Income: The income of the individual.
# Approved: Indicates whether the individual's credit card application was approved.

# %%
# !kaggle datasets download -d thedevastator/uncover-global-trends-in-mental-health-disorder
# Out:
# ...
#  81% 1.00M/1.24M [00:00<00:00, 1.51MB/s]
# 100% 1.24M/1.24M [00:00<00:00, 1.79MB/s]

# %%
# !unzip uncover-global-trends-in-mental-health-disorder.zip
# Out:
# Archive:  uncover-global-trends-in-mental-health-disorder.zip
#   inflating: Mental health Depression disorder Data.csv

# %%
import pandas as pd
df = pd.read_csv('Mental health Depression disorder Data.csv', low_memory=False)

# %%
df.head()
# Out:
#    index       Entity Code  Year Schizophrenia (%) Bipolar disorder (%)  \
# 0      0  Afghanistan  AFG  1990           0.16056             0.697779
# 1      1  Afghanistan  AFG  1991          0.160312             0.697961
# 2      2  Afghanistan  AFG  1992          0.160135             0.698107
# 3      3  Afghanistan  AFG  1993          0.160037             0.698257
# 4      4  Afghanistan  AFG  1994          0.160022             0.698469
#
#   Eating disorders (%)  Anxiety disorders (%)  Drug use disorders (%)  \
# 0             0.101855               4.828830                1.677082
# 1             0.099313               4.829740                1.684746
# 2             0.096692               4.831108                1.694334
# 3             0.094336               4.830864                1.705320
# 4             0.092439               4.829423                1.716069
#
#    Depression (%)  Alcohol use disorders (%)
# 0        4.071831                   0.672404
# ...

# %%
# mean_value_shiz = df['Schizophrenia'].mean()
# print("Mean:", mean_value_shiz)
# median_value_shiz = df['Schizophrenia'].median()
# print("Median:", median_value_shiz)
# mode_value_shiz = df['Schizophrenia'].mode()[0]
# print("Mode:", mode_value_shiz)

# mean_value_bip = df['Bipolar disorder'].mean()
# print("Mean:", mean_value_bip)
# median_value_bip = df['Bipolar disorder'].median()
# print("Median:", median_value_bip)
# mode_value_bip = df['Bipolar disorder'].mode()[0]
# print("Mode:", mode_value_bip)

# mean_value_eating = df['Eating disorders'].mean()
# print("Mean:", mean_value_eating)
# median_value_eating = df['Eating disorders'].median()
# print("Median:", median_value_eating)
# mode_value_eating = df['Eating disorders'].mode()[0]
# print("Mode:", mode_value_eating)

# mean_value_anx = df['Anxiety disorders'].mean()
# print("Mean:", mean_value_anx)
# median_value_anx = df['Anxiety disorders'].median()
# print("Median:", median_value_anx)
# mode_value_anx = df['Anxiety disorders'].mode()[0]
# print("Mode:", mode_value_anx)

# mean_value_drug = df['Drug use disorders'].mean()
# print("Mean:", mean_value_drug)
# median_value_drug = df['Drug use disorders'].median()
# print("Median:", median_value_drug)
# mode_value_drug = df['Drug use disorders'].mode()[0]
# print("Mode:", mode_value_drug)

# mean_value_depr = df['Depression'].mean()
# print("Mean:", mean_value_depr)
# median_value_depr = df['Depression'].median()
# print("Median:", median_value_depr)
# mode_value_depr = df['Depression'].mode()[0]
# print("Mode:", mode_value_depr)

# mean_value_alc = df['Alcohol use disorders'].mean()
# print("Mean:", mean_value_alc)
# median_value_alc = df['Alcohol use disorders'].median()
# print("Median:", median_value_alc)
# mode_value_alc = df['Alcohol use disorders'].mode()[0]
# print("Mode:", mode_value_alc)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 108553 entries, 0 to 108552
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   index                      108553 non-null  int64
#  1   Entity                     108553 non-null  object
#  2   Code                       103141 non-null  object
#  3   Year                       108553 non-null  object
#  4   Schizophrenia (%)          25875 non-null   object
#  5   Bipolar disorder (%)       19406 non-null   object
#  6   Eating disorders (%)       100236 non-null  object
#  7   Anxiety disorders (%)      6468 non-null    float64
#  8   Drug use disorders (%)     6468 non-null    float64
#  9   Depression (%)             6468 non-null    float64
#  10  Alcohol use disorders (%)  6468 non-null    float64
# dtypes: float64(4), int64(1), object(6)
# memory usage: 9.1+ MB

# %% [markdown]
# Entity: Unique identifier for each country or region included in the data set.
# Code: Unique code associated with an Entity/Country or region included in the data set.
# Year: Year that the data about that particular Entity/Country was collected.
# Schizophrenia (%): Percentage of people with schizophrenia in that country/region during that year.
# Bipolar disorder (%): Percentage of people with bipolar disorder in that country/region during that year.
# Eating disorders (%): Percentage of people with eating disorders in that country/region during that year.
# Anxiety disorders (%): Percentage of people with anxiety disorders in that country/region during that year.
# Drug use disorders (%): Percentage of people with drug use disorders in that country/region during that year.
# Depression (%): Percentage of people with depression in that country/region during that year.
# Alcohol use disorders (%): Percentage of people with alcohol use disorders in that country/region during that year.

# %% [markdown]
# ## **Exercise 3: Identifying Data Types**
# **Time Americans Spend Sleeping**
# Year: It is a quantitative variable as it represents a numerical value (integer) that denotes a specific point in time.
#
# Period: It is a qualitative variable as it represents categories or labels rather than numerical values.
#
# Avg hrs per day sleeping: It is a quantitative variable as it represents numerical values.
#
# Standard Error: It is a quantitative variable as it represents numerical values that quantify the variability or uncertainty associated with the average sleep duration.
#
# Type of Days: It is a qualitative variable as it represents categories or labels rather than numerical values.
#
# Age Group: It is a qualitative variable as it represents categories.
#
# Activity: It is a qualitative variable as it represents categories.
#
# Sex: It is a qualitative variable as it represents categories.
#
# **Credit Card Approvals (Clean Data)**
# Gender: It is a qualitative variable as it represents categories. While it may seem like a boolean variable, it still falls under the category of qualitative variables.
#
# Age:  It is a quantitative variable as it represents numerical values.
#
# Debt: It is a quantitative variable as it represents numerical values.
#
# Married: It is a qualitative variable as it represents categories.
#
# BankCustomer: It is a qualitative variable as it represents categories.
#
# Industry: It is a qualitative variable as it represents categories.
#
# Ethnicity: It is a qualitative variable as it represents categories.
#
# YearsEmployed: It is a quantitative variable as it represents numerical values.
#
# PriorDefault: It is a qualitative variable as it represents categories.
#
# Employed: It is a qualitative variable as it represents categories.
#
# CreditScore: It is a quantitative variable as it represents numerical values.
#
# DriversLicense: It is a qualitative variable as it represents categories.
#
# Citizen: It is a qualitative variable as it represents categories.
#
# ZipCode: It is a qualitative variable as it represents categories.
#
# Income: It is a quantitative variable as it represents numerical values.
#
# Approved: It is a qualitative variable as it represents categories.
#
# ** Mental health Depression disorder Data**
# Entity: It is a qualitative variable as it represents categories .
#
# Code: It is also a qualitative variable as it represents categories.
#
# Year: It is a quantitative variable as it represents numerical values.
#
# Schizophrenia (%): It is a quantitative variable as it represents numerical values.
#
# Bipolar disorder (%): It is also a quantitative variable as it represents numerical values.
#
# Eating disorders (%): It is a quantitative variable as it represents numerical values.
#
# Anxiety disorders (%): It is a quantitative variable as it represents numerical values.
#
# Drug use disorders (%): It is a quantitative variable as it represents numerical values.
#
# Depression (%): It is a quantitative variable as it represents numerical values.
#
# Alcohol use disorders (%): It is a quantitative variable as it represents numerical values.

# %%
# !kaggle datasets download -d uciml/iris
# Out:
# ...
#   0% 0.00/3.60k [00:00<?, ?B/s]
# 100% 3.60k/3.60k [00:00<00:00, 8.48MB/s]

# %%
# !unzip iris.zip
# Out:
# Archive:  iris.zip
#   inflating: Iris.csv
#   inflating: database.sqlite

# %%
import pandas as pd
df = pd.read_csv('Iris.csv')

# %%
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %% [markdown]
#  1   SepalLengthCm: It is a quantitative variable as it represents numerical values.
#  2   SepalWidthCm: It is a quantitative variable as it represents numerical values.
#  3   PetalLengthCm: It is a quantitative variable as it represents numerical values.
#  4   PetalWidthCm: It is a quantitative variable as it represents numerical values.
#  5   Species: It is a qualitative variable as it represents categories.
